# %%
#all imports:
import astropy
from astropy.io import fits
from astropy.table import Table
import matplotlib.pyplot as plt
import math
from astroquery.mast import Observations, Mast, MastMissions
from astroquery.simbad import Simbad
import pandas as pd
import numpy as np
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.coordinates import search_around_sky

# %%
#initialitze variables:
k2_table = '/home/gleb/Astronomy/K2_planet_list.csv'
kepler_table = '/home/gleb/Astronomy/Kepler_planet_list.csv'

# %%
k2 = pd.read_csv(k2_table)
kepler = pd.read_csv(kepler_table)
defFlag_mask = k2['default_flag']==1
dispTrue_mask = k2['disposition']=='CONFIRMED'
dispFalse_mask = k2['disposition']=='FALSE POSITIVE'
koiDisp_True_mask = kepler['koi_disposition']=='CONFIRMED'
koiDisp_False_mask = kepler['koi_disposition']=='FALSE POSITIVE'

# %%
allspec = Observations.query_criteria(dataproduct_type = 'spectrum', provenance_name = 'apogee', target_classification = 'STAR')

# %%
k2_targets_negative = k2[defFlag_mask][dispFalse_mask]
# Out:
# /tmp/ipykernel_102755/240419272.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   k2_targets_negative = k2[defFlag_mask][dispFalse_mask]

# %%
allspec_coords = [[],[]]
allspec_coords = [[allspec['s_ra']],[allspec['s_dec']]]

# %%
k2_pos_coords = [[k2_targets_negative['ra']],[k2_targets_negative['dec']]]

# %%
ra_catalog = allspec_coords[0]*u.degree
dec_catalog = allspec_coords[1]*u.degree
ra_target = k2_pos_coords[0]*u.degree
dec_target = k2_pos_coords[1]*u.degree

# %%
target = SkyCoord(ra_target, dec_target)
catalog = SkyCoord(ra_catalog, dec_catalog)

# %%
idx_target, idx_obs, sep, _ = search_around_sky(
    target[0],
    catalog[0],
    2*u.arcsec
)

# %%
k2_negative_obsid = [[],[]]
for i in range(len(idx_target)):
    match_index_target = idx_target[i]
    match_index_catalog = idx_obs[i]
    obj = k2_targets_negative['hostname'][match_index_target-1:match_index_target]
    obsid = allspec['obsid'][match_index_catalog-1:match_index_catalog]
    #print(f"Object: {obj}. Observation: {obsid[0]}")
    k2_negative_obsid[0].append(obj)
    k2_negative_obsid[1].append(obsid[0])

# %%
target_obsids = []
for i in k2_negative_obsid[1]:
    target_obsids.append(str(i))

# %%
target_obsids
# Out:
# ['234042396',
#  '234086956',
#  '234291814',
#  '234173118',
#  '234319133',
#  '234575485',
#  '234596448',
#  '234625780',
#  '234461918',
#  '234556360',
#  '234069373',
#  '234461940',
#  '234563849',
#  '234556521',
#  '234400466',
#  '234080064',
#  '234458631',
#  '233938812',
#  '234599213',
#  '234559258',
#  '234559365',
#  '234360290',
#  '234403709',
#  '234604609',
#  '234416993',
#  '233764438',
#  '234311050',
#  '234418847',
#  '234588167',
#  '234095301',
#  '234323576',
#  '233861393',
#  '234033278',
#  '234033297',
#  '234271830',
#  '234355803',
#  '234334627',
#  '234029263',
#  '234302161',
#  '234334766',
#  '234101480',
#  '234084629',
#  '234154370',
#  '234130030',
#  '234321541',
#  '233794972',
#  '233846596',
#  '234321556',
#  '234616220',
#  '234085055',
#  '234101695',
#  '234520069',
#  '234283010',
#  '233794972',
#  '233846596',
#  '234321556',
#  '234616220',
#  '234085055',
#  '234101695',
#  '234520069',
#  '234283010',
#  '234084539',
#  '234084879',
#  '233927191',
#  '234170824',
#  '234306121',
#  '233927050',
#  '234248305',
#  '233926677',
#  '234170607',
#  '234305932',
#  '233842314',
#  '234248217',
#  '234370558',
#  '234307985',
#  '234370741',
#  '234308575',
#  '234370522',
#  '234308082',
#  '234308226',
#  '234232209',
#  '234101100',
#  '234232206',
#  '234153929',
#  '234128437',
#  '233983471',
#  '234153961',
#  '234085305',
#  '234558439',
#  '234065529']

# %%
len(target_obsids)
# Out:
# 90

# %%
to_load = Observations.filter_products(Observations.get_product_list(target_obsids), dataproduct_type='spectrum', mrp_only=True)

# %%
aspcap_mask=['productSubGroupDescription']=='APSTAR'

# %%
to_load
# Out:
# <Table masked=True length=160>
#   obsID   obs_collection dataproduct_type ... dataRights calib_level filters
#    str9        str4           str12       ...    str6       int64      str4
# --------- -------------- ---------------- ... ---------- ----------- -------
# 233764438           SDSS         spectrum ...     PUBLIC           3    None
# 233764438           SDSS         spectrum ...     PUBLIC           3    None
# 233794972           SDSS         spectrum ...     PUBLIC           3    None
# 233794972           SDSS         spectrum ...     PUBLIC           3    None
# 233842314           SDSS         spectrum ...     PUBLIC           3    None
# 233842314           SDSS         spectrum ...     PUBLIC           3    None
# 233846596           SDSS         spectrum ...     PUBLIC           3    None
# 233846596           SDSS         spectrum ...     PUBLIC           3    None
# 233861393           SDSS         spectrum ...     PUBLIC           3    None
#       ...            ...              ... ...        ...         ...     ...
# 234596448           SDSS         spectrum ...     PUBLIC           3    None
# 234596448           SDSS         spectrum ...     PUBLIC           3    None
# 234599213           SDSS         spectrum ...     PUBLIC           3    None
# 234599213           SDSS         spectrum ...     PUBLIC           3    None
# 234604609           SDSS         spectrum ...     PUBLIC           3    None
# 234604609           SDSS         spectrum ...     PUBLIC           3    None
# 234616220           SDSS         spectrum ...     PUBLIC           3    None
# 234616220           SDSS         spectrum ...     PUBLIC           3    None
# 234625780           SDSS         spectrum ...     PUBLIC           3    None
# 234625780           SDSS         spectrum ...     PUBLIC           3    None

# %%
Observations.download_products(to_load, mrp_only=True)
# Out:
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:SDSS/apogee/apo25m/100%2B60/2M14065551%2B5241077/apStar-dr17-2M14065551%2B5241077.fits to ./mastDownload/SDSS/sdss_apogee_apo25m_100+60_2m14065551+5241077/apStar-dr17-2M14065551+5241077.fits ... [Done]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:SDSS/apogee/apo25m/100%2B60/2M14065551%2B5241077/aspcapStar-dr17-2M14065551%2B5241077.fits to ./mastDownload/SDSS/sdss_apogee_apo25m_100+60_2m14065551+5241077/aspcapStar-dr17-2M14065551+5241077.fits ... [Done]
# <Table length=2>
#                                                Local Path                                                ...
#                                                  str104                                                  ...
# -------------------------------------------------------------------------------------------------------- ...
#     ./mastDownload/SDSS/sdss_apogee_apo25m_100+60_2m14065551+5241077/apStar-dr17-2M14065551+5241077.fits ...
# ./mastDownload/SDSS/sdss_apogee_apo25m_100+60_2m14065551+5241077/aspcapStar-dr17-2M14065551+5241077.fits ...

# %%
new_file = 'aspcapStar-dr17-2M14065551+5241077.fits'

# %%
data = fits.open(new_file)
flux = data[1].data
apogee_wls = np.logspace(data[1].header['CRVAL1'],
                         data[1].header['CRVAL1']+data[1].header['CDELT1']*data[3].header['NAXIS1'],
                         data[1].header['NAXIS1'])
pixel_mask = (data[2].data < 0.1)

# %%
plt.figure(figsize=(20,6))
plt.ylim(0.5, 1.2)
plt.xlim(np.min(apogee_wls[pixel_mask]), np.max(apogee_wls[pixel_mask]))
plt.plot(apogee_wls[pixel_mask], flux[pixel_mask], c='k')
