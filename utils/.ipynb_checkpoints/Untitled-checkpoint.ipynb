# %%
from apogee_multifunc_unpacker import *

# %%
flux_raw, wave = load_fits('/home/gleb/Astronomy/apStar-dr17-2M03342884+2032073.fits', 'ap')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 flux_raw, wave = load_fits('/home/gleb/Astronomy/apStar-dr17-2M03342884+2032073.fits', 'ap')
#
# File ~/Programming/Python/SpectrumAnalyzer/utils/apogee_multifunc_unpacker.py:25, in load_fits(filepath, filetype)
#      17     wave = np.logspace(
#      18         data[1].header["CRVAL1"],
#      19         data[1].header["CRVAL1"]
#      20         + data[1].header["CDELT1"] * data[0].header["NWAVE"],
#      21         data[0].header["NWAVE"],
#      22     )
#      24     pixel_mask = data[2].data < 0.1
# ---> 25     flux_raw = flux_raw[pixel_mask]
#      26     wave = wave[pixel_mask]
#      28 case 'aspcap':
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
flux_raw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 flux_raw
#
# NameError: name 'flux_raw' is not defined

# %%
import numpy as np

# %%
flux_norm = normalize_spectrum(flux_raw)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(25,5))
plt.plot(wave, flux_norm)

# %%
plt.figure(figsize=(25,5))
plt.plot(wave, flux_raw)
